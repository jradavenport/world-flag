# %%
# %matplotlib inline  
import matplotlib.pylab as plt
import matplotlib.colors as colors
from matplotlib.patches import Circle
import numpy as np

# %%
# set up the physical parameters!
rmoon_rearth = 0.272400872
rsun_rearth = 109.045013

# ratio of distance to moon / distance to sun
dmoon_dsun = 0.00256951871

# inclination of moon-earth orbit to earth-sun orbit
# from: http://commons.wikimedia.org/wiki/File%3AEarth-Moon.svg
incl = 5.14*np.pi/180.0

# %%
# now plot it!
scl = 5.0
escl = 2.0

bgclr = 'black'
sclr = 'gold'
eclr = 'royalblue'
mclr = 'GhostWhite'
atmosclr = 'lightblue'

# set figure size to have dimensions (Pi x 2)
fig, ax = plt.subplots(1,1, figsize=(np.pi*scl, 2.0*scl))
ax.set_axis_bgcolor(bgclr)

# place the Sun 1 solar radius down, so Earth crosses at limb
sun =  Circle((0,-rsun_rearth),radius=rsun_rearth, facecolor=sclr, edgecolor='black')
ax.add_patch(sun)

'''
what to color earth? it's not "blue"...
one estimate of average earth color: roughly #132C2E from
http://www.jeffreythompson.org/blog/2014/08/13/average-color-of-the-earth/

but this color is kind ugly here, so go with a blue. 

Make the edge lightblue, because atmosphere
'''

# Earth is unit circle at origin
earth = Circle((0,0),radius=1, facecolor=eclr,
               edgecolor=atmosclr)
ax.add_patch(earth)


#-- Moon offset
# could try relative scaling of distance to moon vs distance to sun
# my = rsun_rearth * dmoon_dsun

# or adjust it artistically
my = 1.5 
mx = np.abs(my*np.sin(incl)/np.sin(np.pi/2-incl)) 
moon = Circle((mx,my),radius=rmoon_rearth, facecolor=mclr, edgecolor='black')
ax.add_patch(moon)


# set plot range based on earth scale
plt.xlim(-escl*np.pi/2.0, escl*np.pi/2.0)
plt.ylim(-escl, escl)

# get rid of ticks/labels
# from: http://stackoverflow.com/a/12998531/4842871
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off
plt.tick_params(axis='y', which='both', 
                left='off', right='off', labelleft='off')

# save figure to file
plt.savefig('world-flag.png', bbox_inches='tight', pad_inches = 0)
plt.show()
# Out:
# /Users/james/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.

# %%
## ALTERNATIVE 1
## scale separations "correctly"

# set figure size to have dimensions (Pi x 2)
fig, ax = plt.subplots(1,1, figsize=(np.pi*scl, 2.0*scl))
ax.set_axis_bgcolor(bgclr)

# place the Sun 1 solar radius down, so Earth crosses at limb
sun =  Circle((0,-rsun_rearth),radius=rsun_rearth, facecolor=sclr, edgecolor='black')
ax.add_patch(sun)

# Earth is unit circle at origin
earth = Circle((0,0),radius=1, facecolor=eclr,
               edgecolor=atmosclr)
ax.add_patch(earth)


#-- Moon offset
# could try relative scaling of distance to moon vs distance to sun
my = rsun_rearth * dmoon_dsun

mx = np.abs(my*np.sin(incl)/np.sin(np.pi/2-incl)) 
moon = Circle((mx,my),radius=rmoon_rearth, facecolor=mclr, edgecolor='black')
ax.add_patch(moon)


# set plot range based on earth scale
plt.xlim(-escl*np.pi/2.0, escl*np.pi/2.0)
plt.ylim(-escl, escl)

# get rid of ticks/labels
# from: http://stackoverflow.com/a/12998531/4842871
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off
plt.tick_params(axis='y', which='both', 
                left='off', right='off', labelleft='off')

# save figure to file
plt.savefig('world-flag-alt1.png', bbox_inches='tight', pad_inches = 0)
plt.show()
# Out:
# /Users/james/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.

# %%
## ALTERNATIVE 2
## artistic separations, but rotate frame into earth's 23.5deg tilt

etilt = 23.4 * np.pi/180.0
mincl = -etilt - incl

# set figure size to have dimensions (Pi x 2)
fig, ax = plt.subplots(1,1, figsize=(np.pi*scl, 2.0*scl))
ax.set_axis_bgcolor(bgclr)

# place the Sun 1 solar radius down, so Earth crosses at limb
sun =  Circle((np.abs(rsun_rearth/1.09*np.sin(etilt)/np.sin(np.pi/2-etilt)), rsun_rearth/1.09),
              radius=rsun_rearth, facecolor=sclr, edgecolor='black')
ax.add_patch(sun)

# Earth is unit circle at origin
earth = Circle((0,0),radius=1, facecolor=eclr,
               edgecolor=atmosclr)
ax.add_patch(earth)


#-- Moon offset
# could try relative scaling of distance to moon vs distance to sun
# my = rsun_rearth * dmoon_dsun

my = 1.3
mx = np.abs(my*np.sin(mincl)/np.sin(np.pi/2-mincl))
moon = Circle((-mx,-my), radius=rmoon_rearth, facecolor=mclr, edgecolor='black')
ax.add_patch(moon)


# set plot range based on earth scale
plt.xlim(-escl*np.pi/2.0, escl*np.pi/2.0)
plt.ylim(-escl, escl)

# get rid of ticks/labels
# from: http://stackoverflow.com/a/12998531/4842871
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off
plt.tick_params(axis='y', which='both', 
                left='off', right='off', labelleft='off')

# save figure to file
plt.savefig('world-flag-alt2.png', bbox_inches='tight', pad_inches = 0)
plt.show()
# Out:
# /Users/james/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.

# %%
## ALTERNATIVE 2
## artistic separations, but rotate frame into earth's 23.5deg tilt

etilt = 23.4 * np.pi/180.0
mincl = -etilt - incl

# set figure size to have dimensions (Pi x 2)
fig, ax = plt.subplots(1,1, figsize=(3,3))
ax.set_axis_bgcolor(bgclr)

# place the Sun 1 solar radius down, so Earth crosses at limb
sun =  Circle((np.abs(rsun_rearth/1.09*np.sin(etilt)/np.sin(np.pi/2-etilt)), rsun_rearth/1.09),
              radius=rsun_rearth, facecolor=sclr, edgecolor='black')
ax.add_patch(sun)

# Earth is unit circle at origin
earth = Circle((0,0),radius=1, facecolor=eclr,
               edgecolor=atmosclr)
ax.add_patch(earth)


#-- Moon offset
# could try relative scaling of distance to moon vs distance to sun
# my = rsun_rearth * dmoon_dsun

my = 1.3
mx = np.abs(my*np.sin(mincl)/np.sin(np.pi/2-mincl))
moon = Circle((-mx,-my), radius=rmoon_rearth, facecolor=mclr, edgecolor='black')
ax.add_patch(moon)


# set plot range based on earth scale
plt.xlim(-escl*0.8, escl*0.8)
plt.ylim(-escl*0.8, escl*0.8)

# get rid of ticks/labels
# from: http://stackoverflow.com/a/12998531/4842871
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off
plt.tick_params(axis='y', which='both', 
                left='off', right='off', labelleft='off')

# save figure to file
plt.savefig('world-flag-thumb.png', bbox_inches='tight', pad_inches = 0)
plt.show()
# Out:
# /Users/james/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.

# %%
# Adam Frank suggests I look at MARS... 

mars_clr = '#D05A41'
# set up the physical parameters!
rsun_rmars = 205.2545155

# inclination of moon orbits to ecliptic plane
incl_phobos = 26.04*np.pi/180.0
incl_deimos = 27.58*np.pi/180.0

a_deimos = 23463.2 # km
a_phobos = 9376. # km

rdeimos_rphobos = 6.2 / 11.26

# %%
# set figure size to have dimensions (Pi x 2)
fig, ax = plt.subplots(1,1, figsize=(np.pi*scl, 2.0*scl))
ax.set_axis_bgcolor(bgclr)

# place the Sun 1 solar radius down, so Earth crosses at limb
sun =  Circle((-rsun_rmars,0),radius=rsun_rmars, facecolor=sclr, edgecolor='black')
ax.add_patch(sun)

# Earth is unit circle at origin
mars = Circle((0,0),radius=1, facecolor=mars_clr,
               edgecolor='black')
ax.add_patch(mars)


#-- put the 2 little moons on
pscl = 1.2 # for artistic scaling
mx = pscl * np.cos(incl_phobos)
my = pscl * np.sin(incl_phobos)
plt.scatter(mx,my, marker=(4,1,0), s=80, c=mclr)

mx = pscl*a_deimos/a_phobos * np.cos(incl_deimos)
my = pscl*a_deimos/a_phobos * np.sin(incl_deimos)
plt.scatter(mx,my, marker=(4,1,0), s=80*rdeimos_rphobos, c=mclr)


# set plot range based on earth scale
plt.xlim(-escl*np.pi/2.0, escl*np.pi/2.0)
plt.ylim(-escl, escl)

# get rid of ticks/labels
# from: http://stackoverflow.com/a/12998531/4842871
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off
plt.tick_params(axis='y', which='both', 
                left='off', right='off', labelleft='off')

# save figure to file
plt.savefig('mars-flag-alt1.png', bbox_inches='tight', pad_inches = 0)
plt.show()
# Out:
# /Users/james/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   app.launch_new_instance()
